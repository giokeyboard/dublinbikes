# %%
import requests    #to send the request to the API
from bs4 import BeautifulSoup
import time        #to set the delay time of invoking the API

import MySQLdb     #to set up the database connecction
HOST = "dublinbikes.cb2pu3bkmmlf.us-east-2.rds.amazonaws.com"
USERNAME = "master"
PASSWORD = "master-50"
DATABASE = "dublinbikes"


def get_count():   #function to call the api
    url = "https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey=e91c3125a3ebb07cf4eb407dee6251d324dfba9c"
  

    # Request with fake header, otherwise you will get an 403 HTTP error sometimes. It might work without this as well
    r = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})

    # Parse the JSON
    data = r.json()
   
    return data
def station():
    value=get_count()
    db = MySQLdb.connect(HOST,USERNAME, PASSWORD, DATABASE)
# prepare a cursor object using cursor() method
    cursor = db.cursor()
    for i in range(0,len(value)):
        value_1=value[i]
        address_d=value_1['address']
        banking_d=value_1['banking']
        bike_stands_d=value_1['bike_stands']
        bonus_d=value_1['bonus']
        contact_name_d=value_1['contract_name']
        number_d=value_1['number']
        position_lat_d=value_1['position']['lat']
        position_lng_d=value_1['position']['lng']
        status_d=value_1['status']
        sql = """INSERT INTO dublinbikes.station (address,banking,bike_stands,bonus,contract_name,number,position_lat,position_lng,status) VALUES ('%s','%s','%s','%s','%s','%s','%s','%s','%s')""" % (address_d,banking_d,bike_stands_d,bonus_d,contact_name_d,number_d,position_lat_d,position_lng_d,status_d)
        try:
            print("Line 1 ")
            cursor.execute(sql) # Execute the SQL command
            print(cursor._last_executed)
            #print("Line 2")
            db.commit() # Commit your changes in the database
            print("data inserted successfully")

    
        except:
        
            db.rollback()
            #print(cursor._last_executed)
            print("Not working")
        
        # Rollback in case there is any error
        
 # disconnect from server
    db.close()
station()

while True:
    
    
   # print(get_count())   #Calling the function after a delay of 300 seconds or 5 minutes
    value=get_count()     #Calling the get_count function to invoke the API
    # Open database connection
    db = MySQLdb.connect(HOST,USERNAME, PASSWORD, DATABASE)
# prepare a cursor object using cursor() method
    cursor = db.cursor()
    for i in range(0,len(value)):
        value_1=value[i]
        number_d=value_1['number']
        #print("Number is",station_id)
        available_bikes_d=value_1['available_bikes']
        #print("Station is",station_name)
        available_bike_stands_d=value_1['available_bike_stands']
        #print("Available is",number_bikes_available)
        #print(type(number_bikes_available))
        #Save event data to database
        last_update_d=value_1['last_update']
        # Prepare QL query to INSERT a record into the database.
        #sql= """INSERT INTO mydb.dynamic_data_6 (available) VALUES ('%s')""" % (number_bikes_available)
        sql = """INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('%s','%s','%s','%s')""" % (number_d,available_bikes_d,available_bike_stands_d,last_update_d)
        try:
            print("Line 1 ")
            cursor.execute(sql) # Execute the SQL command
            print(cursor._last_executed)
            #print("Line 2")
            db.commit() # Commit your changes in the database
            print("data inserted successfully")
    
    
        except:
        
            db.rollback()
            #print(cursor._last_executed)
            print("Not working")
        
        # Rollback in case there is any error
        
 # disconnect from server
    db.close()
    
    time.sleep(400)
    #VALUES ('%s','%s','%s','%s','%s','%s')""" % (1,Tweet.text,User.screen_name,score,search_type,User.location)
# Out:
# Line 1
# b"INSERT INTO dublinbikes.station (address,banking,bike_stands,bonus,contract_name,number,position_lat,position_lng,status) VALUES ('Smithfield North','True','30','False','Dublin','42','53.349562','-6.278198','OPEN')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.station (address,banking,bike_stands,bonus,contract_name,number,position_lat,position_lng,status) VALUES ('Parnell Square North','True','20','False','Dublin','30','53.353462','-6.265305','OPEN')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.station (address,banking,bike_stands,bonus,contract_name,number,position_lat,position_lng,status) VALUES ('Clonmel Street','False','33','False','Dublin','54','53.336021','-6.26298','OPEN')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.station (address,banking,bike_stands,bonus,contract_name,number,position_lat,position_lng,status) VALUES ('Avondale Road','False','40','False','Dublin','108','53.359405','-6.276142','OPEN')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.station (address,banking,bike_stands,bonus,contract_name,number,position_lat,position_lng,status) VALUES ('Mount Street Lower','False','40','False','Dublin','56','53.33796','-6.24153','OPEN')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.station (address,banking,bike_stands,bonus,contract_name,number,position_lat,position_lng,status) VALUES ('Christchurch Place','False','20','False','Dublin','6','53.343368','-6.27012','OPEN')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.station (address,banking,bike_stands,bonus,contract_name,number,position_lat,position_lng,status) VALUES ('Grantham Street','True','30','False','Dublin','18','53.334123','-6.265436','OPEN')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.station (address,banking,bike_stands,bonus,contract_name,number,position_lat,position_lng,status) VALUES ('Pearse Street','True','30','False','Dublin','32','53.344304','-6.250427','OPEN')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.station (address,banking,bike_stands,bonus,contract_name,number,position_lat,position_lng,status) VALUES 
OPEN')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.station (address,banking,bike_stands,bonus,contract_name,number,position_lat,position_lng,status) VALUES ('Heuston Bridge (North)','False','40','False','Dublin','92','53.347802','-6.292432','OPEN')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.station (address,banking,bike_stands,bonus,contract_name,number,position_lat,position_lng,status) VALUES ('Leinster Street South','False','30','False','Dublin','21','53.34218','-6.254485','OPEN')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.station (address,banking,bike_stands,bonus,contract_name,number,position_lat,position_lng,status) VALUES ('Blackhall Place','False','30','False','Dublin','88','53.3488','-6.281637','OPEN')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('42','28','2','1550625774000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('30','1','19','1550625762000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('54','2','31','1550625750000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('108','17','22','1550626110000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('56','2','38','1550625959000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('6','1','19','1550625875000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('18','2','28','1550625829000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('32','1','29','1550625789000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('52','0','32','1550625774000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('48','2','38','1550625845000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('13','3','27','1550625816000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('43','30','0','1550625793000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('81','26','14','1550625800000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('31','1','19','1550625790000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('98','0','40','1550625784000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('14','0','30','1550625757000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('23','4','26','1550625796000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('106','2','38','1550625809000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('112','25','5','1550625809000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('68','0','40','1550625814000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('74','27','3','1550625810000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('87','38','0','1550625812000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('84','30','0','1550625797000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('90','2','38','1550625803000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('11','0','30','1550625803000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('17','0','20','1550625772000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('45','15','15','1550626119000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('114','0','40','1550625794000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('72','19','12','1550625794000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('63','0','35','1550625807000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('113','0','40','1550625764000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('91','17','13','1550625820000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('99','0','30','1550625812000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('9','1','23','1550625657000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('67','37','3','1550625791000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('55','0','36','1550625777000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('62','0','40','1550625803000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('5','19','21','1550625809000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('97','33','7','1550626146000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('61','5','20','1550625798000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('77','1','28','1550625761000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('73','10','20','1550625780000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('4','0','20','1550625777000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('49','0','40','1550625798000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('19','1','29','1550625747000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('7','5','24','1550625754000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('60','30','0','1550625766000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('102','23','17','1550625791000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('38','0','40','1550625817000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('53','0','40','1550625777000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('58','0','40','1550625770000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('66','30','10','1550625768000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('104','0','40','1550625797000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('101','22','8','1550625774000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('115','30','0','1550625872000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('47','3','37','1550625811000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('8','0','30','1550625802000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('27','1','19','1550625826000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('16','0','20','1550625775000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('96','8','22','1550625769000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('82','19','3','1550626083000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('76','25','13','1550625775000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('71','3','37','1550625773000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('79','7','20','1550625787000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('69','4','36','1550625771000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('25','0','30','1550625752000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('51','0','40','1550625773000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('37','0','30','1550625755000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('59','8','12','1550625757000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('95','40','0','1550625813000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('94','32','8','1550625810000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('105','0','36','1550625760000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('36','0','40','1550625761000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('93','34','6','1550625810000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('22','0','20','1550625798000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('50','40','0','1550625763000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('110','24','16','1550625819000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('12','19','1','1550625775000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('34','29','1','1550625762000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('78','24','16','1550625775000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('2','14','6','1550625788000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('75','39','1','1550625785000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('111','24','16','1550625851000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('26','1','19','1550625798000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('65','2','38','1550625809000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('15','3','13','1550625777000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('86','33','5','1550625818000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('35','9','21','1550626002000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('10','0','16','1550625766000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('100','18','7','1550625775000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('24','0','20','1550625746000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('64','2','38','1550625813000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('109','29','0','1550626075000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('85','29','6','1550625785000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('107','12','28','1550626058000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('33','0','23','1550625788000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('44','30','0','1550625752000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('89','0','40','1550625798000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('57','0','23','1550625786000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('80','39','1','1550625898000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('41','2','18','1550625775000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('3','5','15','1550625774000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('46','0','19','1550625868000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('40','1','20','1550625756000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('29','1','28','1550625780000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('70','14','14','1550625824000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('103','17','23','1550625766000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('28','7','23','1550626254000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('39','4','16','1550625785000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('83','31','9','1550625795000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('92','35','5','1550625815000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('21','3','27','1550625792000')"
# data inserted successfully
# Line 1
# b"INSERT INTO dublinbikes.availability (number,available_bikes,available_bike_stands,last_update) VALUES ('88','29','1','1550625787000')"
# data inserted successfully
